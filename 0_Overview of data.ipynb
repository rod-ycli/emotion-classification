# %% [markdown]
# # 0. Overview of Data

# %%
import pandas as pd
import spacy
from spacy import displacy
import nltk

# %% [markdown]
# ## 0.1 Loading the MELD data set

# %%
filepath = './data/MELD/train_sent_emo.csv'
meld_train = pd.read_csv(filepath)
### The data has some problematic strings with encoding problems. The next code removes some of these from the utterances
# Try to fix encoding
meld_train['Utterance'] = meld_train['Utterance'].str.replace("\x92|\x97|\x91|\x93|\x94|\x85", "'")
# Out:
# <ipython-input-2-ec9ebc47ff2e>:5: FutureWarning: The default value of regex will change from True to False in a future version.
#   meld_train['Utterance'] = meld_train['Utterance'].str.replace("\x92|\x97|\x91|\x93|\x94|\x85", "'")

# %%
# Removing 'Neutral'

meld_train = meld_train.set_index("Emotion", drop=False)
meld_train = meld_train.drop("neutral", axis=0)
meld_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5279 entries, surprise to joy
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sr No.        5279 non-null   int64
#  1   Utterance     5279 non-null   object
#  2   Speaker       5279 non-null   object
#  3   Emotion       5279 non-null   object
#  4   Sentiment     5279 non-null   object
#  5   Dialogue_ID   5279 non-null   int64
#  6   Utterance_ID  5279 non-null   int64
#  7   Season        5279 non-null   int64
#  8   Episode       5279 non-null   int64
#  9   StartTime     5279 non-null   object
#  10  EndTime       5279 non-null   object
# dtypes: int64(5), object(6)
# memory usage: 494.9+ KB

# %%
meld_train.head()
# Out:
#           Sr No.                                          Utterance   Speaker  \
# Emotion
# surprise       5                             My duties?  All right.  Chandler
# fear          11                             No don't I beg of you!  Chandler
# surprise      13                                           Really?!  Chandler
# surprise      15  But then who? The waitress I went out with las...      Joey
# sadness       16                               You know? Forget it!    Rachel
#
#            Emotion Sentiment  Dialogue_ID  Utterance_ID  Season  Episode  \
# Emotion
# surprise  surprise  positive            0             4       8       21
# fear          fear  negative            0            10       8       21
# surprise  surprise  positive            0            12       8       21
# surprise  surprise  negative            1             0       9       23
# sadness    sadness  negative            1             1       9       23
#
#              StartTime       EndTime
# Emotion
# surprise  00:16:34,452  00:16:40,917
# fear      00:17:02,856  00:17:04,858
# surprise  00:17:13,491  00:17:16,536
# surprise  00:36:40,364  00:36:42,824
# sadness   00:36:44,368  00:36:46,578

# %% [markdown]
# ### Looking at examples of each emotion:

# %%
examples = dict()

for index, utterance in enumerate(meld_train['Utterance'][:500]):
    emotion_label = meld_train['Emotion'].iloc[index]
    if emotion_label not in examples.keys():
        new_val = []
        examples[emotion_label] = new_val
        new_val.append(utterance)
    else:
        examples[emotion_label].append(utterance)
    
for eg in examples.items():
    print(eg[0].upper())
    for num, sent in enumerate(eg[1][:15]):
        print(num+1, sent)
    print()
# Out:
# SURPRISE
# 1 My duties?  All right.
# 2 Really?!
# 3 But then who? The waitress I went out with last month?
# 4 No-no-no-no, no! Who, who were you talking about?
# 5 No way!
# 6 Oh my God, oh my God! Poor Monica!
# 7 What, what, what?!
# 8 What?!
# 9 He thinks Monica is empty, she is the empty vase!
# 10 Hey!
# 11 What are you doing here?
# 12 Everybody!!
# 13 You liked it? You really liked it?
# 14 I was surprised to see a kangaroo in a World War I epic.
# 15 Look!
#
# FEAR
# 1 No don't I beg of you!
# 2 No, I-I-I-I don't, I actually don't know
# 3 Well, I-I got this blinding pain in my stomach when I was lifting weights before, then I uh passed out and uh, haven't been able to stand up since.
# 4 No way! 'Kay look, if I have to go to the doctor for anything it's gonna be for this thing sticking out of my stomach!
# 5 Oh boy, I just can't watch. It's too scary!
# 6 Oh yeah well, you know me, babies, responsibilities, ahhh!!!
# 7 Uh-oh.
# 8 I know!  Don't switch hands, okay?
# 9 What should I wear, now I'm all nervous.
# 10 I think you've got concussion.
# 11 You're welcome.  I'm sorry. Did I hurt you?
# 12 That's funny. Umm'.  It's not funny.
# 13 Umm, but I think if you give me umm, one chance I can, I can change your mind.
# 14 She is gonna hate me.
# 15 Will you marry me?
#
# SADNESS
# 1 You know? Forget it!
# 2 Chris says they're closing down the bar.
# 3 Got me.
# 4 Oh, totally. Oh, God, oh, she seemed so happy too.
# 5 Listen, I'm ah, I'm sorry I've been so crazy and jealous and, it's just that I like you a lot, so...
# 6 Don't go!
# 7 I'm sorry.
# 8 I'm so sorry!
# 9 Uh, well... Joey and I broke up.
# 10 Joey is a great guy, but we're just... so different! I mean, during your speech he kept laughing at homo erectus!
# 11 Anyway I just, uh, I think it's for the best.
# 12 I guess.
# 13 I have to pee. And Rachel's in the bathroom!
# 14 Man, this is gonna be kinda weird.
# 15 Okay, come on, I can't get married until I get something old, something new, something borrowed, and something blue.
#
# JOY
# 1 Do I ever.
# 2 You betcha!
# 3 Um-mm, yeah right!
# 4 Hi!
# 5 Oh well, the woman I interviewed with was pretty tough, but y'know thank God Mark coached me, because once I started talking about the fall line, she got all happy and wouldn't shut up.
# 6 I'm so proud of you.
# 7 Me too!
# 8 Good job Joe! Well done! Top notch!
# 9 Oh-ho-ho, yeah!
# 10 I love the specifics, the specifics were the best part!
# 11 Great! Okay, here.
# 12 Thank you. Thank you. Thank you!  And
# 13 Can you hold on a moment? I have another call.  I love her.
# 14 Ok.  Ok. Having a phone has finally paid off.
# 15 Here you go Phoebe! Here you go Phobo! Phewbedo! Phaybobo.
#
# DISGUST
# 1 Just coffee! Where are we gonna hang out now?
# 2 Oh my god. You are pure evil.
# 3 That's great, but shouldn't you be on the toilet right now?
# 4 What's wrong with you?
# 5 That's a hernia.
# 6 Oy!!
# 7 My grandmother has this new boyfriend, and they're both kind of insecure in bed.
# 8 You have no idea how loud they are!
# 9 Ew! What is that? Something exploded!
# 10 Hey lady! I don't care how much you want it! Okay?! I am
# 11 And-and-and-and-and the toothpicks?
# 12 Well, I don't understand why Adrienne's attracted to Victor.
# 13 Hey, hang up! You get food poisoning just talkin' to that place.
# 14 You're one to talk.
# 15 Oh man. Please tell me one of 'em is Ma.
#
# ANGER
# 1 Oh no-no-no, give me some specifics.
# 2 You fell asleep!!
# 3 There was no kangaroo!
# 4 They didn't take any of my suggestions!
# 5 This guy fell asleep!
# 6 He fell asleep too!
# 7 Be mad at him!
# 8 Or, call an ambulance.
# 9 What?! What is with everybody? It's Thanksgiving, not...Truth-Day!
# 10 Ok, pure evil , horny and alone . I've done this
# 11 Nobody!
# 12 Nobody respects the bucket!
# 13 You wouldn't believe what people put in here!
# 14 Look!
# 15 Okay, does this look like a garbage can to you?

# %% [markdown]
# The shape of the data:ANGER
# 1 Oh no-no-no, give me some specifics.
# 2 You fell asleep!!
# 3 There was no kangaroo!
# 4 They didn't take any of my suggestions!
# 5 This guy fell asleep!
# 6 He fell asleep too!
# 7 Be mad at him!
# 8 Or, call an ambulance.
# 9 What?! What is with everybody? It's Thanksgiving, not...Truth-Day!
# 10 Ok, pure evil , horny and alone . I've done this
# 11 Nobody!
# 12 Nobody respects the bucket!
# 13 You wouldn't believe what people put in here!
# 14 Look!
# 15 Okay, does this look like a garbage can to you?

# %%
meld_train.Emotion.value_counts()
# Out:
# joy         1743
# surprise    1205
# anger       1109
# sadness      683
# disgust      271
# fear         268
# Name: Emotion, dtype: int64

# %% [markdown]
# ## 0.2 Loading the Tweets data set, and looking at examples of each emotion

# %%
filepath = './data/wassa/training/all.train.tsv'
tweets_train = pd.read_csv(filepath, sep='\t')

examples = dict()

for index, utterance in enumerate(tweets_train['Tweet']):
    emotion_label = tweets_train['Label'].iloc[index]
    if emotion_label not in examples.keys():
        new_val = []
        examples[emotion_label] = new_val
        new_val.append(utterance)
    else:
        examples[emotion_label].append(utterance)
    
for eg in examples.items():
    print(eg[0].upper())
    for num, sent in enumerate(eg[1][:15]):
        print(num+1, sent)
    print()
# Out:
# ANGER
# 1 How the fu*k! Who the heck! moved my fridge!... should I knock the landlord door. #angry #mad ##
# 2 So my Indian Uber driver just called someone the N word. If I wasn't in a moving vehicle I'd have jumped out #disgusted
# 3 @DPD_UK I asked for my parcel to be delivered to a pick up store not my address #fuming #poorcustomerservice
# 4 so ef whichever butt wipe pulled the fire alarm in davis bc I was sound asleep #pissed #angry #upset #tired #sad #tired #hangry ######
# 5 Don't join @BTCare they put the phone down on you, talk over you and are rude. Taking money out of my acc willynilly! #fuming
# 6 My blood is boiling
# 7 When you've still got a whole season of Wentworth to watch and a stupid cunt in work ruins it for us 😭😭 @__KirstyGA #raging #oldcunt
# 8 @bt_uk why does tracking show my equipment delivered, when it wasn't? Why is my service suddenly delayed? We've already 3 weeks. #fuming
# 9 @TeamShanny legit why i am so furious with him, people are such fucking idiots.
# 10 How is it suppose to work if you do that? Wtf dude? Thanks for pissing me off.
# 11 im so mad about power rangers. im incensed. im furious.
# 12 Wont use using @mothercareuk @Mothercarehelp again!! These guys cant get nothing right!! #fuming
# 13 Bitches aggravate like what inspires you to be the biggest cunt known to man kind?
# 14 Why does @dapperlaughs have to come to Glasgow on a night I am working. I am fucking gutted, been waiting for an appearance for ages #raging
# 15 Fuking fuming 😤
#
# FEAR
# 1 I feel like I am drowning. #depression #anxiety #falure #worthless
# 2 I get so nervous even thinking about talking to ****** I wanna die
# 3 I lost my blinders .... #panic
# 4 I feel like I am drowning. #depression  #falure #worthless
# 5 This is the scariest American Horror Story out of all of them... I'm gonna have to watch in the daytime. #frightened
# 6 @mgcsartwork I nearly started crying and having a full on panic attack after tatinof bc of the crowds so I feel him
# 7 I have to finally tell my therapist about my sexuality ... last frontier ... not sure I can do it in the AM #fear #SingleGirlProblems
# 8 @laura221b I don't think I've ever moved so fast in a panic in all my life 😂 Gave me such a fright 😓
# 9 My bus was in a car crash... I'm still shaking a bit... This week was an absolute horror and this was the icing on the cake... #terrible
# 10 My bus was in a car crash... I'm still shaking a bit... This week was an absolute horror and this was the icing on the cake...
# 11 procrasting is fun until im an hour away from the time its due and i still havent finished so i have a panic attack
# 12 My #anxiety is rising tonight and I'm not sure why. Sometimes I wonder if I'm a magnet for any free-floating anxiety in the universe.
# 13 Im not a #nervouswreck, Im a #nervous #pileup. #GoingCrazy #HelpMe #Insane #Antisocial
# 14 #panic Panic attack from fear of starting new medication
# 15 Job interview in the afternoon #nervous #ek
#
# JOY
# 1 Just got back from seeing @GaryDelaney in Burslem. AMAZING!! Face still hurts from laughing so much #hilarious
# 2 Oh dear an evening of absolute hilarity I don't think I have laughed so much in a long time! 😂
# 3 Been waiting all week for this game ❤️❤️❤️ #cheer #friday ❤️
# 4 @gardiner_love : Thank you so much, Gloria! You're so sweet, and thoughtful! You just made my day more joyful! I love you too! 😊💕
# 5 I feel so blessed to work with the family that I nanny for ❤️ nothing but love &amp; appreciation, makes me smile.
# 6 Today I reached 1000 subscribers on YT!! , #goodday, #thankful
# 7 @Singaholic121 Good morning, love! Happy first day of fall. Let's make some awesome #autumnmemories #annabailey #laughter #smile
# 8 #BridgetJonesBaby is the best thing I've seen in ages! So funny, I've missed Bridget! #love  #TeamMark
# 9 Just got back from seeing @GaryDelaney in Burslem. AMAZING!! Face still hurts from laughing so much
# 10 @IndyMN I thought the holidays could not get any more cheerful, and then I met you. #TheNiceBot
# 11 I'm just still . So happy .\nA blast
# 12 It's meant to be!! #happy #happy
# 13 💥⚖️Yeah‼️ PAUL‼️⚖️💥  #glorious #BB18
# 14 My morning started off amazing!! Hopefully the whole day is going as i want it to go!\n #GreatDay
# 15 😱 @cailamarsai you've had me 😂 😂 the whole time watching @black_ishABC after you've lost your #glasses! It was #hilarious! @mrbabyboogaloo
#
# SADNESS
# 1 Depression sucks! #depression
# 2 Feeling worthless as always #depression
# 3 Feeling worthless as always
# 4 My #Fibromyalgia has been really bad lately which is not good for my mental state. I feel very overwhelmed #anxiety #bipolar #depression
# 5 Im think ima lay in bed all day and sulk. Life is hitting me to hard rn
# 6 So when I try I fail... and when I don't try... I still fail... #confused and #lost
# 7 Extreme sadness
# 8 my life in one word is depressing
# 9 Panic attacks are the worst. Feeling really sick and still shaking. I should be a sleep. #anxiety #depression
# 10 Feel so grim + ugly atm
# 11 Honestly depression is kicking my ass lately.. 😔
# 12 At my age all I see is gray. Is it gray because of my bad eyes or my perspective #depression  #healingjustice
# 13 After 3 idk why I start feeling so depress, sad and lonely.
# 14 I sulk too much for my own good.
# 15 A night where depression is winning... #depression #fml #help

# %% [markdown]
# The shape of the data:

# %%
tweets_train.info()
tweets_train.Label.value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3613 entries, 0 to 3612
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ID      3613 non-null   int64
#  1   Tweet   3613 non-null   object
#  2   Label   3613 non-null   object
#  3   Score   3613 non-null   float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 113.0+ KB
# fear       1147
# anger       857
# joy         823
# sadness     786
# Name: Label, dtype: int64

# %% [markdown]
# ## 0.3 Understand the dependencies and POS of some samples

# %%
some_sample = ""
for tweet in tweets_train['Tweet'][:20]:
    some_sample += f"{tweet} "

# %%
nlp = spacy.load("en_core_web_sm")
doc = nlp(some_sample)

# %%
displacy.render(doc, jupyter=True, style='dep')
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="da950b24028041f48a4e8041eb2bd72e-0" class="displacy" width="66550" height="1274.5" direction="ltr" style="max-width: none; height: 1274.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">How</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">fu*k!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">Who</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">heck!</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">INTJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">moved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">fridge!...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">should</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">knock</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">landlord</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">door. #</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">angry #</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">mad ##</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">So</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3200">my</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3375">Indian</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3375">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3550">Uber</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3550">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3725">driver</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3725">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="3900">just</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3900">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4075">called</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4250">someone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4425">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4425">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4600">N</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4600">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4775">word.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4775">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="4950">If</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4950">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="5125">I</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="5125">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="1184.5">
#     <tspan class="displacy-word" fill="currentColor" x="5300">was</tspan>
#     <tspan class="displacy-tag" dy="2em

# %%
subj_list = []
for token in list(doc):
    if token.dep_ == "nsubj": #or token.dep_ == "nsubjpass":
        subj_list.append(token)

print(subj_list)
# Out:
# [I, driver, I, I, I, wipe, I, #, #, they, #, you, cunt, tracking, equipment, it, We, i, people, it, you, i, i, i, guys, Bitches, what, @dapperlaughs, I, #, that, guy, 's, blood, I, it, I, people, he, I, I, everyone]

# %%
nltk_sents = nltk.tokenize.sent_tokenize(some_sample)
for sent in nltk_sents:
    tokens = nltk.tokenize.word_tokenize(sent)
    postagged = nltk.pos_tag(tokens)
    print(postagged)
# Out:
# [('How', 'WRB'), ('the', 'DT'), ('fu', 'NN'), ('*', 'NNP'), ('k', 'NN'), ('!', '.')]
# [('Who', 'WP'), ('the', 'DT'), ('heck', 'NN'), ('!', '.')]
# [('moved', 'VBN'), ('my', 'PRP$'), ('fridge', 'NN'), ('!', '.'), ('...', ':')]
# [('should', 'MD'), ('I', 'PRP'), ('knock', 'VB'), ('the', 'DT'), ('landlord', 'NN'), ('door', 'NN'), ('.', '.')]
# [('#', '#'), ('angry', 'JJ'), ('#', '#'), ('mad', 'JJ'), ('#', '#'), ('#', '#'), ('So', 'NNP'), ('my', 'PRP$'), ('Indian', 'JJ'), ('Uber', 'NNP'), ('driver', 'NN'), ('just', 'RB'), ('called', 'VBD'), ('someone', 'NN'), ('the', 'DT'), ('N', 'NNP'), ('word', 'NN'), ('.', '.')]
# [('If', 'IN'), ('I', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('in', 'IN'), ('a', 'DT'), ('moving', 'VBG'), ('vehicle', 'NN'), ('I', 'PRP'), ("'d", 'MD'), ('have', 'VB'), ('jumped', 'VBN'), ('out', 'RP'), ('#', '#'), ('disgusted', 'JJ'), ('@', 'NNP'), ('DPD_UK', 'NNP'), ('I', 'PRP'), ('asked', 'VBD'), ('for', 'IN'), ('my', 'PRP$'), ('parcel', 'NN'), ('to', 'TO'), ('be', 'VB'), ('delivered', 'VBN'), ('to', 'TO'), ('a', 'DT'), ('pick', 'NN'), ('up', 'RP'), ('store', 'NN'), ('not', 'RB'), ('my', 'PRP$'), ('address', 'NN'), ('#', '#'), ('fuming', 'VBG'), ('#', '#'), ('poorcustomerservice', 'NN'), ('so', 'RB'), ('ef', 'JJ'), ('whichever', 'NN'), ('butt', 'NN'), ('wipe', 'WDT'), ('pulled', 'VBD'), ('the', 'DT'), ('fire', 'NN'), ('alarm', 'NN'), ('in', 'IN'), ('davis', 'JJ'), ('bc', 'NN'), ('I', 'PRP'), ('was', 'VBD'), ('sound', 'JJ'), ('asleep', 'RB'), ('#', '#'), ('pissed', 'JJ'), ('#', '#'), ('angry', 'JJ'), ('#', '#'), ('upset', 'JJ'), ('#', '#'), ('tired', 'JJ'), ('#', '#'), ('sad', 'JJ'), ('#', '#'), ('tired', 'JJ'), ('#', '#'), ('hangry', 'JJ'), ('#', '#'), ('#', '#'), ('#', '#'), ('#', '#'), ('#', '#'), ('#', '#'), ('Do', 'VBP'), ("n't", 'RB'), ('join', 'VB'), ('@', 'NNP'), ('BTCare', 'NNP'), ('they', 'PRP'), ('put', 'VBD'), ('the', 'DT'), ('phone', 'NN'), ('down', 'RP'), ('on', 'IN'), ('you', 'PRP'), (',', ','), ('talk', 'VB'), ('over', 'IN'), ('you', 'PRP'), ('and', 'CC'), ('are', 'VBP'), ('rude', 'JJ'), ('.', '.')]
# [('Taking', 'VBG'), ('money', 'NN'), ('out', 'IN'), ('of', 'IN'), ('my', 'PRP$'), ('acc', 'NN'), ('willynilly', 'RB'), ('!', '.')]
# [('#', '#'), ('fuming', 'VBG'), ('My', 'PRP$'), ('blood', 'NN'), ('is', 'VBZ'), ('boiling', 'VBG'), ('When', 'WRB'), ('you', 'PRP'), ("'ve", 'VBP'), ('still', 'RB'), ('got', 'VBD'), ('a', 'DT'), ('whole', 'JJ'), ('season', 'NN'), ('of', 'IN'), ('Wentworth', 'NNP'), ('to', 'TO'), ('watch', 'VB'), ('and', 'CC'), ('a', 'DT'), ('stupid', 'JJ'), ('cunt', 'NN'), ('in', 'IN'), ('work', 'NN'), ('ruins', 'NNS'), ('it', 'PRP'), ('for', 'IN'), ('us', 'PRP'), ('😭😭', 'VBP'), ('@', 'JJ'), ('__KirstyGA', 'NNP'), ('#', '#'), ('raging', 'VBG'), ('#', '#'), ('oldcunt', 'NN'), ('@', 'NNP'), ('bt_uk', 'NN'), ('why', 'WRB'), ('does', 'VBZ'), ('tracking', 'VBG'), ('show', 'VB'), ('my', 'PRP$'), ('equipment', 'NN'), ('delivered', 'VBN'), (',', ','), ('when', 'WRB'), ('it', 'PRP'), ('was', 'VBD'), ("n't", 'RB'), ('?', '.')]
# [('Why', 'WRB'), ('is', 'VBZ'), ('my', 'PRP$'), ('service', 'NN'), ('suddenly', 'RB'), ('delayed', 'VBN'), ('?', '.')]
# [('We', 'PRP'), ("'ve", 'VBP'), ('already', 'RB'), ('3', 'CD'), ('weeks', 'NNS'), ('.', '.')]
# [('#', '#'), ('fuming', 'VBG'), ('@', 'JJ'), ('TeamShanny', 'NNP'), ('legit', 'NN'), ('why', 'WRB'), ('i', 'NN'), ('am', 'VBP'), ('so', 'RB'), ('furious', 'JJ'), ('with', 'IN'), ('him', 'PRP'), (',', ','), ('people', 'NNS'), ('are', 'VBP'), ('such', 'JJ'), ('fucking', 'JJ'), ('idiots', 'NNS'), ('.', '.')]
# [('How', 'WRB'), ('is', 'VBZ'), ('it', 'PRP'), ('suppose', 'JJ'), ('to', 'TO'), ('work', 'VB'), ('if', 'IN'), ('you', 'PRP'), ('do', 'VBP'), ('that', 'DT'), ('?', '.')]
# [('Wtf', 'NNP'), ('dude', 'NN'), ('?', '.')]
# [('Thanks', 'NNS'), ('for', 'IN'), ('pissing', 'VBG'), ('me', 'PRP'), ('off', 'RP'), ('.', '.')]
# [('im', 'NNS'), ('so', 'RB'), ('mad', 'JJ'), ('about', 'IN'), ('power', 'NN'), ('rangers', 'NNS'), ('.', '.')]
# [('im', 'NN'), ('incensed', 'VBD'), ('.', '.')]
# [('im', 'RB'), ('furious', 'JJ'), ('.', '.')]
# [('Wont', 'NNP'), ('use', 'NN'), ('using', 'VBG'), ('@', 'JJ'), ('mothercareuk', 'NN'), ('@', 'NNP'), ('Mothercarehelp', 'NNP'), ('again', 'RB'), ('!', '.'), ('!', '.')]
# [('These', 'DT'), ('guys', 'NNS'), ('cant', 'VBP'), ('get', 'VB'), ('nothing', 'NN'), ('right', 'RB'), ('!', '.'), ('!', '.')]
# [('#', '#'), ('fuming', 'VBG'), ('Bitches', 'NNP'), ('aggravate', 'NN'), ('like', 'IN'), ('what', 'WP'), ('inspires', 'VBZ'), ('you', 'PRP'), ('to', 'TO'), ('be', 'VB'), ('the', 'DT'), ('biggest', 'JJS'), ('cunt', 'NN'), ('known', 'VBN'), ('to', 'TO'), ('man', 'NN'), ('kind', 'NN'), ('?', '.')]
# [('Why', 'WRB'), ('does', 'VBZ'), ('@', 'VB'), ('dapperlaughs', 'NNS'), ('have', 'VBP'), ('to', 'TO'), ('come', 'VB'), ('to', 'TO'), ('Glasgow', 'NNP'), ('on', 'IN'), ('a', 'DT'), ('night', 'NN'), ('I', 'PRP'), ('am', 'VBP'), ('working', 'VBG'), ('.', '.')]
# [('I', 'PRP'), ('am', 'VBP'), ('fucking', 'VBG'), ('gutted', 'VBN'), (',', ','), ('been', 'VBN'), ('waiting', 'VBG'), ('for', 'IN'), ('an', 'DT'), ('appearance', 'NN'), ('for', 'IN'), ('ages', 'NNS'), ('#', '#'), ('raging', 'VBG'), ('Fuking', 'VBG'), ('fuming', 'VBG'), ('😤', 'NN'), ('Zero', 'NNP'), ('help', 'NN'), ('from', 'IN'), ('@', 'JJ'), ('ups', 'NNS'), ('customer', 'NN'), ('service', 'NN'), ('.', '.')]
# [('Just', 'RB'), ('pushing', 'VBG'), ('the', 'DT'), ('buck', 'NN'), ('back', 'RB'), ('and', 'CC'), ('forth', 'NN'), ('and', 'CC'), ('promising', 'NN'), ('callbacks', 'NNS'), ('that', 'WDT'), ('don', 'VBP'), ('’', 'JJ'), ('t', 'NN'), ('happen', 'NN'), ('.', '.')]
# [('#', '#'), ('anger', 'NN'), ('#', '#'), ('loathing', 'VBG'), ('@', 'NN'), ('ArizonaCoyotes', 'VBZ'), ('not', 'RB'), ('to', 'TO'), ('mention', 'VB'), ('the', 'DT'), ('GRA', 'NNP'), ('guy', 'NN'), ('stops', 'VBZ'), ('me', 'PRP'), ('but', 'CC'), ('let', 'VB'), ("'s", 'VBZ'), ('the', 'DT'), ('2', 'CD'), ('ppl', 'NN'), ('in', 'IN'), ('front', 'NN'), ('of', 'IN'), ('me', 'PRP'), ('go', 'VBP'), ('.', '.')]
# [('WTF', 'NNP'), ('.', '.')]
# [('My', 'PRP$'), ('blood', 'NN'), ('is', 'VBZ'), ('boiling', 'VBG'), ('.', '.')]
# [('I', 'PRP'), ('hate', 'VBP'), ('my', 'PRP$'), ('lawn', 'NN'), ('mower', 'NN'), ('.', '.')]
# [('If', 'IN'), ('it', 'PRP'), ('had', 'VBD'), ('a', 'DT'), ('soul', 'NN'), (',', ','), ('I', 'PRP'), ("'d", 'MD'), ('condemn', 'VB'), ('it', 'PRP'), ('to', 'TO'), ('the', 'DT'), ('fiery', 'NN'), ('pits', 'NNS'), ('of', 'IN'), ('Hell', 'NNP'), ('.', '.')]
# [('why', 'WRB'), ('are', 'VBP'), ('people', 'NNS'), ('so', 'RB'), ('offended', 'VBN'), ('by', 'IN'), ('kendall', 'NN'), ('he', 'PRP'), ('ends', 'VBZ'), ('photo', 'JJ'), ('shoot', 'NN'), ('like', 'IN'), ('seriously', 'RB'), ('shut', 'VBN'), ('the', 'DT'), ('fuck', 'NN'), ('up', 'RP'), ('I', 'PRP'), ("'m", 'VBP'), ('about', 'IN'), ('to', 'TO'), ('block', 'VB'), ('everyone', 'NN'), ('everywhere', 'RB'), ('posting', 'VBG'), ('about', 'IN'), ('the', 'DT'), ('storm', 'NN'), ('.', '.')]
# [('I', 'PRP'), ('think', 'VBP'), ('everyone', 'NN'), ('is', 'VBZ'), ('aware', 'JJ'), ('of', 'IN'), ('the', 'DT'), ('damn', 'NN'), ('rain', 'NN'), ('and', 'CC'), ('what', 'WP'), ('not', 'RB'), ('so', 'RB'), ('quit', 'RB'), ('.', '.')]
# [('#', '#'), ('damn', 'NN')]

# %%
teststr = "no-no, no, no one is taking no for an answer."
print(nltk.pos_tag(nltk.tokenize.word_tokenize(teststr)))
# Out:
# [('no-no', 'JJ'), (',', ','), ('no', 'DT'), (',', ','), ('no', 'DT'), ('one', 'NN'), ('is', 'VBZ'), ('taking', 'VBG'), ('no', 'DT'), ('for', 'IN'), ('an', 'DT'), ('answer', 'NN'), ('.', '.')]

# %%
testonspacy = nlp(teststr)
[(word.text, word.tag_) for word in list(testonspacy)]
# Out:
# [('no', 'UH'),
#  ('-', 'HYPH'),
#  ('no', 'UH'),
#  (',', ','),
#  ('no', 'UH'),
#  (',', ','),
#  ('no', 'DT'),
#  ('one', 'NN'),
#  ('is', 'VBZ'),
#  ('taking', 'VBG'),
#  ('no', 'RB'),
#  ('for', 'IN'),
#  ('an', 'DT'),
#  ('answer', 'NN'),
#  ('.', '.')]

# %%
for word in doc.sents:
    print(word.text)
# Out:
# How the fu*k!
# Who the heck!
# moved my fridge!...
# should I knock the landlord door.
# #angry #mad ##
# So my Indian Uber driver just called someone the N word.
# If I wasn't in a moving vehicle I'd have jumped out #disgusted  @DPD_UK I asked for my parcel to be delivered to a pick up store not my address #fuming #poorcustomerservice so ef whichever butt wipe pulled the fire alarm in davis bc
# I was sound asleep #pissed #angry #upset
# #tired #sad #tired #hangry ###### Don't join @BTCare they put the phone down on you, talk over you and are rude.
# Taking money out of my acc willynilly!
# #fuming My blood is boiling When you've still got a whole season of Wentworth to watch and a stupid cunt in work ruins it for us 😭
# 😭
# @__KirstyGA #raging #oldcunt @bt_uk why does tracking show my equipment delivered, when it wasn't?
# Why is my service suddenly delayed?
# We've already 3 weeks.
# #fuming @TeamShanny legit why i am so furious with him, people are such fucking idiots.
# How is it suppose to work if you do that?
# Wtf dude?
# Thanks for pissing me off.
#  im so mad about power rangers.
# im incensed.
# im furious.
# Wont use using @mothercareuk @Mothercarehelp again!!
# These guys cant get nothing right!!
# #fuming Bitches aggravate like what inspires you to be the biggest cunt known to man kind?
# Why does @dapperlaughs have to come to Glasgow on a night I am working.
# I am fucking gutted, been waiting for an appearance for ages #raging Fuking fuming 😤 Zero help from @ups customer service.
# Just pushing the buck back and forth and promising callbacks that don’t happen.
# #anger #loathing @ArizonaCoyotes not to mention the GRA guy stops me but let's the 2 ppl in front of me go.
# WTF.
# My blood is boiling.
# I hate my lawn mower.
# If it had a soul, I'd condemn it to the fiery pits of Hell.
# why are people so offended by kendall he ends photo shoot like seriously shut the fuck up
# I'm about to block everyone everywhere posting about the storm.
# I think everyone is aware of the damn rain and what not so quit.
# #damn

# %%
spacy_tok_test = "Sorry-but you're...? People say I'm, 'Pip.'"

runtest = nlp(spacy_tok_test.lower())

for tok in runtest:
    print(tok)
# Out:
# sorry
# -
# but
# you
# 're
# ...
# ?
# people
# say
# i
# 'm
# ,
# '
# pip
# .
# '
